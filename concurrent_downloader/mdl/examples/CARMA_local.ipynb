# %%
import sys
module_path = "/home/ecastillo/repositories/concurrent_downloader"
sys.path.insert(0,module_path)
print(sys.path)
# Out:
# ['/home/ecastillo/repositories/concurrent_downloader', '/home/ecastillo/repositories/concurrent_downloader/examples', '/opt/seiscomp3/lib/python', '/home/ecastillo/repositories/concurrent_downloader/examples', '/home/ecastillo/.vscode-server/extensions/ms-python.python-2020.9.114305/pythonFiles', '/home/ecastillo/.vscode-server/extensions/ms-python.python-2020.9.114305/pythonFiles/lib/python', '/home/ecastillo/anaconda3/envs/eqt/lib/python37.zip', '/home/ecastillo/anaconda3/envs/eqt/lib/python3.7', '/home/ecastillo/anaconda3/envs/eqt/lib/python3.7/lib-dynload', '', '/home/ecastillo/anaconda3/envs/eqt/lib/python3.7/site-packages', '/home/ecastillo/anaconda3/envs/eqt/lib/python3.7/site-packages/IPython/extensions', '/home/ecastillo/.ipython']

# %%
from bulk_downloader import BulkDownloader
from obspy.clients.fdsn.mass_downloader.domain import RectangularDomain
from obspy.clients.fdsn.mass_downloader import Restrictions
from obspy.core.utcdatetime import UTCDateTime

##Definición del client
IRIS_client = {"base_url":"IRIS"}  

##Definición de las restricciones
YU_restrictions = Restrictions(starttime=UTCDateTime(2016, 8, 1),
                        endtime=UTCDateTime(2016, 8, 3),
                        network="YU", 
                        station="CS*",
                        location="*", channel="*",
                        chunklength_in_sec=86400,
                        reject_channels_with_gaps=False,
                        minimum_length=0.0,
                        minimum_interstation_distance_in_m=0.0,
                        channel_priorities=[],
                        location_priorities=[""])
##Dominio de carma
domainR = RectangularDomain(minlatitude=6, maxlatitude=14,
                    minlongitude=-80, maxlongitude=-68)

## Almacenamiento
## Poner {<SDSdir>} al inicio para indicar que es formato SDS
mseed_storage = ("{<SDSdir>}:/home/ecastillo/download/CARMA/waveforms")
stationxml_storage = "/home/ecastillo/download/CARMA/stations/{network}/{station}.xml"

#Instancie objeto y descargue
bdl = BulkDownloader(client_dict=IRIS_client)

#consulte la información del método download_by_station
print(bdl.download_by_station.__doc__)
# Out:
#         Parallel download by each station.
#
#         Parameters
#         ----------
#         domain: class:'obspy.mass_downloader.domain'
#             The download domain.
#         restrictions: class:'obspy.mass_downloader.restrictions.Restrictions'
#             Non-spatial downloading restrictions.
#         mseed_storage: str
#             Where to store the waveform files.
#             If it has '{<SDSdir>}:' then it is going to save in SDS format.
#             key parameters for controlling the store: {network}, {station},
#             {location},{channel}, {starttime}, and {endtime}
#         stationxml_storage: str
#             Where to store the StationXML files.
#             key parameters for controlling the store: {network}, {station},
#             {location},{channel}, {starttime}, and {endtime}
#         workers: int
#             Number of subprocess that will be used.
#         parallel_mode: str
#             It can be 'thread' or 'process'. However It's recommended
#             to use 'process'because by 'thread' you only can use 6 workers
#             because for greater workers the downloading is not complete
#             due to no FDSN response.
#
#         returns
#         -------
#         mseed files and xml files in mseed_storage and stationxml_storage
#         respectively.

# %%
bdl.download_by_station(domain=domainR,
                    restrictions=YU_restrictions, 
                    mseed_storage=mseed_storage,
                    stationxml_storage=stationxml_storage,
                    workers=4,parallel_mode="process")
# Out:
# rvice.iris.edu' - Successfully downloaded 7 channels (of 7)
# [2020-10-26 15:42:55,111] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - Launching basic QC checks...
# [2020-10-26 15:42:55,111] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - Launching basic QC checks...
# [2020-10-26 15:42:55,158] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - Downloaded 33.9 MB [121.55 KB/sec] of data, 0.0 MB of which were discarded afterwards.
# [2020-10-26 15:42:55,158] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - Downloaded 33.9 MB [121.55 KB/sec] of data, 0.0 MB of which were discarded afterwards.
# [2020-10-26 15:42:55,160] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - Status for 9 time intervals/channels after downloading: DOWNLOADED
# [2020-10-26 15:42:55,160] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - Status for 9 time intervals/channels after downloading: DOWNLOADED
# [2020-10-26 15:42:55,162] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - Status for 9 time intervals/channels after downloading: EXISTS
# [2020-10-26 15:42:55,162] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - Status for 9 time intervals/channels after downloading: EXISTS
# [2020-10-26 15:42:55,173] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - No station information to download.
# [2020-10-26 15:42:55,173] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - No station information to download.
# [2020-10-26 15:42:55,175] - obspy.clients.fdsn.mass_downloader - INFO: ============================== Final report
# [2020-10-26 15:42:55,175] - obspy.clients.fdsn.mass_downloader - INFO: ============================== Final report
# [2020-10-26 15:42:55,176] - obspy.clients.fdsn.mass_downloader - INFO: 9 MiniSEED files [34.8 MB] already existed.
# [2020-10-26 15:42:55,176] - obspy.clients.fdsn.mass_downloader - INFO: 9 MiniSEED files [34.8 MB] already existed.
# [2020-10-26 15:42:55,178] - obspy.clients.fdsn.mass_downloader - INFO: 1 StationXML files [0.3 MB] already existed.
# [2020-10-26 15:42:55,178] - obspy.clients.fdsn.mass_downloader - INFO: 1 StationXML files [0.3 MB] already existed.
# [2020-10-26 15:42:55,179] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - Acquired 9 MiniSEED files [33.9 MB].
# [2020-10-26 15:42:55,179] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - Acquired 9 MiniSEED files [33.9 MB].
# [2020-10-26 15:42:55,181] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - Acquired 0 StationXML files [0.0 MB].
# [2020-10-26 15:42:55,181] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - Acquired 0 StationXML files [0.0 MB].
# [2020-10-26 15:42:55,182] - obspy.clients.fdsn.mass_downloader - INFO: Downloaded 33.9 MB in total.
# [2020-10-26 15:42:55,182] - obspy.clients.fdsn.mass_downloader - INFO: Downloaded 33.9 MB in total.
#
# ** done with -->	YU -- CS01 --> 	time: 285.72 s
# in process
#
# ** loading -->	YU -- CS08
# [2020-10-26 15:42:55,188] - obspy.clients.fdsn.mass_downloader - INFO: Total acquired or preexisting stations: 0
# [2020-10-26 15:42:55,188] - obspy.clients.fdsn.mass_downloader - INFO: Total acquired or preexisting stations: 0
# [2020-10-26 15:42:55,189] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - Requesting reliable availability.
# [2020-10-26 15:42:55,189] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - Requesting reliable availability.
# [2020-10-26 15:42:55,629] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - Successfully requested availability (0.44 seconds)
# [2020-10-26 15:42:55,629] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - Successfully requested availability (0.44 seconds)
# [2020-10-26 15:42:55,632] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - Found 1 stations (9 channels).
# [2020-10-26 15:42:55,632] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - Found 1 stations (9 channels).
# [2020-10-26 15:42:55,634] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - Will attempt to download data from 1 stations.
# [2020-10-26 15:42:55,634] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - Will attempt to download data from 1 stations.
# [2020-10-26 15:42:55,636] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - Status for 9 time intervals/channels before downloading: EXISTS
# [2020-10-26 15:42:55,636] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - Status for 9 time intervals/channels before downloading: EXISTS
# [2020-10-26 15:42:55,638] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - Status for 9 time intervals/channels before downloading: NEEDS_DOWNLOADING
# [2020-10-26 15:42:55,638] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - Status for 9 time intervals/channels before downloading: NEEDS_DOWNLOADING
# [2020-10-26 15:43:03,763] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - Successfully downloaded 7 channels (of 7)
# [2020-10-26 15:43:03,763] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - Successfully downloaded 7 channels (of 7)
# [2020-10-26 15:43:03,765] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - Launching basic QC checks...
# [2020-10-26 15:43:03,765] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - Launching basic QC checks...
# [2020-10-26 15:43:03,810] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - Downloaded 34.8 MB [121.36 KB/sec] of data, 0.0 MB of which were discarded afterwards.
# [2020-10-26 15:43:03,810] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - Downloaded 34.8 MB [121.36 KB/sec] of data, 0.0 MB of which were discarded afterwards.
# [2020-10-26 15:43:03,812] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - Status for 9 time intervals/channels after downloading: DOWNLOADED
# [2020-10-26 15:43:03,812] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - Status for 9 time intervals/channels after downloading: DOWNLOADED
# [2020-10-26 15:43:03,813] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - Status for 9 time intervals/channels after downloading: EXISTS
# [2020-10-26 15:43:03,813] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - Status for 9 time intervals/channels after downloading: EXISTS
# [2020-10-26 15:43:03,823] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - No station information to download.
# [2020-10-26 15:43:03,823] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - No station information to download.
# [2020-10-26 15:43:03,825] - obspy.clients.fdsn.mass_downloader - INFO: ============================== Final report
# [2020-10-26 15:43:03,825] - obspy.clients.fdsn.mass_downloader - INFO: ============================== Final report
# [2020-10-26 15:43:03,826] - obspy.clients.fdsn.mass_downloader - INFO: 9 MiniSEED files [32.5 MB] already existed.
# [2020-10-26 15:43:03,826] - obspy.clients.fdsn.mass_downloader - INFO: 9 MiniSEED files [32.5 MB] already existed.
# [2020-10-26 15:43:03,828] - obspy.clients.fdsn.mass_downloader - INFO: 1 StationXML files [0.3 MB] already existed.
# [2020-10-26 15:43:03,828] - obspy.clients.fdsn.mass_downloader - INFO: 1 StationXML files [0.3 MB] already existed.
# [2020-10-26 15:43:03,829] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - Acquired 9 MiniSEED files [34.8 MB].
# [2020-10-26 15:43:03,829] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - Acquired 9 MiniSEED files [34.8 MB].
# [2020-10-26 15:43:03,830] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - Acquired 0 StationXML files [0.0 MB].
# [2020-10-26 15:43:03,830] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - Acquired 0 StationXML files [0.0 MB].
# [2020-10-26 15:43:03,831] - obspy.clients.fdsn.mass_downloader - INFO: Downloaded 34.8 MB in total.
# [2020-10-26 15:43:03,831] - obspy.clients.fdsn.mass_downloader - INFO: Downloaded 34.8 MB in total.
#
# ** done with -->	YU -- CS04 --> 	time: 294.37 s
# [2020-10-26 15:44:20,615] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - Successfully downloaded 2 channels (of 2)
# [2020-10-26 15:44:20,615] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - Successfully downloaded 2 channels (of 2)
# [2020-10-26 15:45:29,956] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - Successfully downloaded 2 channels (of 2)
# [2020-10-26 15:45:29,956] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - Successfully downloaded 2 channels (of 2)
# [2020-10-26 15:45:30,082] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - Successfully downloaded 2 channels (of 2)
# [2020-10-26 15:45:30,082] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - Successfully downloaded 2 channels (of 2)
# [2020-10-26 15:45:36,624] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - Successfully downloaded 7 channels (of 7)
# [2020-10-26 15:45:36,624] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - Successfully downloaded 7 channels (of 7)
# [2020-10-26 15:45:36,627] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - Launching basic QC checks...
# [2020-10-26 15:45:36,627] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - Launching basic QC checks...
# [2020-10-26 15:45:36,652] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - Downloaded 24.7 MB [118.52 KB/sec] of data, 0.0 MB of which were discarded afterwards.
# [2020-10-26 15:45:36,652] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - Downloaded 24.7 MB [118.52 KB/sec] of data, 0.0 MB of which were discarded afterwards.
# [2020-10-26 15:45:36,654] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - Status for 9 time intervals/channels after downloading: DOWNLOADED
# [2020-10-26 15:45:36,654] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - Status for 9 time intervals/channels after downloading: DOWNLOADED
# [2020-10-26 15:45:36,656] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - Status for 9 time intervals/channels after downloading: EXISTS
# [2020-10-26 15:45:36,656] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - Status for 9 time intervals/channels after downloading: EXISTS
# [2020-10-26 15:45:36,674] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - No station information to download.
# [2020-10-26 15:45:36,674] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - No station information to download.
# [2020-10-26 15:45:36,677] - obspy.clients.fdsn.mass_downloader - INFO: ============================== Final report
# [2020-10-26 15:45:36,677] - obspy.clients.fdsn.mass_downloader - INFO: ============================== Final report
# [2020-10-26 15:45:36,679] - obspy.clients.fdsn.mass_downloader - INFO: 9 MiniSEED files [24.7 MB] already existed.
# [2020-10-26 15:45:36,679] - obspy.clients.fdsn.mass_downloader - INFO: 9 MiniSEED files [24.7 MB] already existed.
# [2020-10-26 15:45:36,680] - obspy.clients.fdsn.mass_downloader - INFO: 1 StationXML files [0.3 MB] already existed.
# [2020-10-26 15:45:36,680] - obspy.clients.fdsn.mass_downloader - INFO: 1 StationXML files [0.3 MB] already existed.
# [2020-10-26 15:45:36,682] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - Acquired 9 MiniSEED files [24.7 MB].
# [2020-10-26 15:45:36,682] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - Acquired 9 MiniSEED files [24.7 MB].
# [2020-10-26 15:45:36,684] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - Acquired 0 StationXML files [0.0 MB].
# [2020-10-26 15:45:36,684] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - Acquired 0 StationXML files [0.0 MB].
# [2020-10-26 15:45:36,685] - obspy.clients.fdsn.mass_downloader - INFO: Downloaded 24.7 MB in total.
# [2020-10-26 15:45:36,685] - obspy.clients.fdsn.mass_downloader - INFO: Downloaded 24.7 MB in total.
#
# ** done with -->	YU -- CS06 --> 	time: 214.25 s
# [2020-10-26 15:46:49,115] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - Successfully downloaded 7 channels (of 7)
# [2020-10-26 15:46:49,115] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - Successfully downloaded 7 channels (of 7)
# [2020-10-26 15:46:49,118] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - Launching basic QC checks...
# [2020-10-26 15:46:49,118] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - Launching basic QC checks...
# [2020-10-26 15:46:49,142] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - Downloaded 27.1 MB [118.67 KB/sec] of data, 0.0 MB of which were discarded afterwards.
# [2020-10-26 15:46:49,142] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - Downloaded 27.1 MB [118.67 KB/sec] of data, 0.0 MB of which were discarded afterwards.
# [2020-10-26 15:46:49,143] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - Status for 9 time intervals/channels after downloading: DOWNLOADED
# [2020-10-26 15:46:49,143] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - Status for 9 time intervals/channels after downloading: DOWNLOADED
# [2020-10-26 15:46:49,145] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - Status for 9 time intervals/channels after downloading: EXISTS
# [2020-10-26 15:46:49,145] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - Status for 9 time intervals/channels after downloading: EXISTS
# [2020-10-26 15:46:49,154] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - No station information to download.
# [2020-10-26 15:46:49,154] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - No station information to download.
# [2020-10-26 15:46:49,156] - obspy.clients.fdsn.mass_downloader - INFO: ============================== Final report
# [2020-10-26 15:46:49,156] - obspy.clients.fdsn.mass_downloader - INFO: ============================== Final report
# [2020-10-26 15:46:49,157] - obspy.clients.fdsn.mass_downloader - INFO: 9 MiniSEED files [27.2 MB] already existed.
# [2020-10-26 15:46:49,157] - obspy.clients.fdsn.mass_downloader - INFO: 9 MiniSEED files [27.2 MB] already existed.
# [2020-10-26 15:46:49,159] - obspy.clients.fdsn.mass_downloader - INFO: 1 StationXML files [0.3 MB] already existed.
# [2020-10-26 15:46:49,159] - obspy.clients.fdsn.mass_downloader - INFO: 1 StationXML files [0.3 MB] already existed.
# [2020-10-26 15:46:49,161] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - Acquired 9 MiniSEED files [27.1 MB].
# [2020-10-26 15:46:49,161] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - Acquired 9 MiniSEED files [27.1 MB].
# [2020-10-26 15:46:49,163] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - Acquired 0 StationXML files [0.0 MB].
# [2020-10-26 15:46:49,163] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - Acquired 0 StationXML files [0.0 MB].
# [2020-10-26 15:46:49,164] - obspy.clients.fdsn.mass_downloader - INFO: Downloaded 27.1 MB in total.
# [2020-10-26 15:46:49,164] - obspy.clients.fdsn.mass_downloader - INFO: Downloaded 27.1 MB in total.
#
# ** done with -->	YU -- CS08 --> 	time: 233.98 s
# [2020-10-26 15:46:57,189] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - Successfully downloaded 7 channels (of 7)
# [2020-10-26 15:46:57,189] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - Successfully downloaded 7 channels (of 7)
# [2020-10-26 15:46:57,192] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - Launching basic QC checks...
# [2020-10-26 15:46:57,192] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - Launching basic QC checks...
# [2020-10-26 15:46:57,220] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - Downloaded 30.8 MB [120.03 KB/sec] of data, 0.0 MB of which were discarded afterwards.
# [2020-10-26 15:46:57,220] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - Downloaded 30.8 MB [120.03 KB/sec] of data, 0.0 MB of which were discarded afterwards.
# [2020-10-26 15:46:57,222] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - Status for 9 time intervals/channels after downloading: DOWNLOADED
# [2020-10-26 15:46:57,222] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - Status for 9 time intervals/channels after downloading: DOWNLOADED
# [2020-10-26 15:46:57,223] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - Status for 9 time intervals/channels after downloading: EXISTS
# [2020-10-26 15:46:57,223] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - Status for 9 time intervals/channels after downloading: EXISTS
# [2020-10-26 15:46:57,234] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - No station information to download.
# [2020-10-26 15:46:57,234] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - No station information to download.
# [2020-10-26 15:46:57,236] - obspy.clients.fdsn.mass_downloader - INFO: ============================== Final report
# [2020-10-26 15:46:57,236] - obspy.clients.fdsn.mass_downloader - INFO: ============================== Final report
# [2020-10-26 15:46:57,237] - obspy.clients.fdsn.mass_downloader - INFO: 9 MiniSEED files [30.8 MB] already existed.
# [2020-10-26 15:46:57,237] - obspy.clients.fdsn.mass_downloader - INFO: 9 MiniSEED files [30.8 MB] already existed.
# [2020-10-26 15:46:57,239] - obspy.clients.fdsn.mass_downloader - INFO: 1 StationXML files [0.3 MB] already existed.
# [2020-10-26 15:46:57,239] - obspy.clients.fdsn.mass_downloader - INFO: 1 StationXML files [0.3 MB] already existed.
# [2020-10-26 15:46:57,240] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - Acquired 9 MiniSEED files [30.8 MB].
# [2020-10-26 15:46:57,240] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - Acquired 9 MiniSEED files [30.8 MB].
# [2020-10-26 15:46:57,241] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - Acquired 0 StationXML files [0.0 MB].
# [2020-10-26 15:46:57,241] - obspy.clients.fdsn.mass_downloader - INFO: Client 'http://service.iris.edu' - Acquired 0 StationXML files [0.0 MB].
# [2020-10-26 15:46:57,243] - obspy.clients.fdsn.mass_downloader - INFO: Downloaded 30.8 MB in total.
# [2020-10-26 15:46:57,243] - obspy.clients.fdsn.mass_downloader - INFO: Downloaded 30.8 MB in total.
#
# ** done with -->	YU -- CS07 --> 	time: 263.24 s
#
# ** TOTAL DOWNLOAD TIME	527.86 s
